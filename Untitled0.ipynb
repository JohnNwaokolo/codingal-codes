# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnNwaokolo/codingal-codes/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def prints(n):
    if n<= 0:
        return
    print("Codingal")
    prints(n/2)
    prints(n/2)
